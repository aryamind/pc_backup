# %%
import numpy as np
import scipy.io.wavfile
from scipy.fftpack import dct
import matplotlib.pyplot as plt

sample_rate, signal = scipy.io.wavfile.read('OSR_us_000_0010_8k.wav')  # File assumed to be in the same directory
# signal = signal[0:int(3.5 * sample_rate)] # Keep the first 3.5 seconds

# %%
signal # mono audio
# Out:
# array([ -919, -1314, -1049, ...,  -330,  -320,  -300], dtype=int16)

# %%
sample_rate # if sample_rate = 8000 means samples per second (i.e., 8 kHz)
# Out:
# 8000

# %%
signal = signal[0:int(3.5 * sample_rate)] # Keep the first 3.5 seconds
len(signal)
# Out:
# 28000

# %%
# Create time axis in seconds
time = np.linspace(0, len(signal) / sample_rate, num=len(signal))
# Plot waveform
plt.figure(figsize=(12, 4))
plt.plot(time, signal)
plt.title("Waveform of Audio Signal")
plt.xlabel("Time (seconds)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
pre_emphasis = 0.97
emphasized_signal = np.append(signal[0], signal[1:] - pre_emphasis * signal[:-1])

# %%
# Create time axis in seconds
time = np.linspace(0, len(emphasized_signal) / sample_rate, num=len(emphasized_signal))
# Plot waveform
plt.figure(figsize=(12, 4))
plt.plot(time, emphasized_signal)
plt.title("Waveform of Audio Signal")
plt.xlabel("Time (seconds)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.tight_layout()
plt.show()
